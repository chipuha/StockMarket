# %%
import pandas as pd
import numpy as np
import pickle

# %%
filename = '../Data/Data/Form4s.pkl'

file = open(filename, 'rb')
data_dict = pickle.load(file)
file.close()

# %%
data_dict
# Out:
#                                                     URL        Date  \
# 0     https://www.sec.gov/Archives/edgar/data/158080...  2020-01-06
# 1     https://www.sec.gov/Archives/edgar/data/158080...  2020-02-13
# 2     https://www.sec.gov/Archives/edgar/data/158080...  2020-02-18
# 3     https://www.sec.gov/Archives/edgar/data/177752...  2019-10-01
# 4     https://www.sec.gov/Archives/edgar/data/177752...  2019-10-01
# ...                                                 ...         ...
# 1270  https://www.sec.gov/Archives/edgar/data/176054...  2020-01-29
# 1271  https://www.sec.gov/Archives/edgar/data/124456...  2020-02-18
# 1272  https://www.sec.gov/Archives/edgar/data/938549...  2020-01-13
# 1273  https://www.sec.gov/Archives/edgar/data/357294...  2020-01-13
# 1274  https://www.sec.gov/Archives/edgar/data/118448...  2019-12-09
#
#       Issuer CIK                 Issuer Name Issuer Ticker   Owner CIK  \
# 0     0001580808          A10 Networks, Inc.          ATEN  0001726563
# ...
