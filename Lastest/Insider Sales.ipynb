# %%
import pandas as pd
import numpy as np
import pickle

# %%
# Unpickle data
filename = '../Data/Data/Form4s.pkl'

file = open(filename, 'rb')
data_dict = pickle.load(file)
file.close()

# %%
data_dict.head()
# Out:
#                                                  URL        Date  Issuer CIK  \
# 0  https://www.sec.gov/Archives/edgar/data/158080...  2020-01-06  0001580808
# 1  https://www.sec.gov/Archives/edgar/data/158080...  2020-02-13  0001580808
# 2  https://www.sec.gov/Archives/edgar/data/158080...  2020-02-18  0001580808
# 3  https://www.sec.gov/Archives/edgar/data/177752...  2019-10-01  0001777529
# 4  https://www.sec.gov/Archives/edgar/data/177752...  2019-10-01  0001777529
#
#                   Issuer Name Issuer Ticker   Owner CIK            Owner Name  \
# 0          A10 Networks, Inc.          ATEN  0001726563  White Christopher P.
# 1          A10 Networks, Inc.          ATEN  0001358721      COCHRAN ROBERT D
# 2          A10 Networks, Inc.          ATEN  0001720596          Reiss Gunter
# 3  A3 Alternative Credit Fund         AAACX  0001786705       Bell Gregory L.
# 4  A3 Alternative Credit Fund         AAACX  0001786705       Bell Gregory L.
#
# ...
